# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

# %%
data = pd.read_csv(r"C:\Users\user\Downloads\Energy_consumption.csv")

# %%
data
# Out:
#                Timestamp  Temperature   Humidity  SquareFootage  Occupancy  \
# 0    2022-01-01 00:00:00    25.139433  43.431581    1565.693999          5
# 1    2022-01-01 01:00:00    27.731651  54.225919    1411.064918          1
# 2    2022-01-01 02:00:00    28.704277  58.907658    1755.715009          2
# 3    2022-01-01 03:00:00    20.080469  50.371637    1452.316318          1
# 4    2022-01-01 04:00:00    23.097359  51.401421    1094.130359          9
# ..                   ...          ...        ...            ...        ...
# 995  2022-02-11 11:00:00    28.619382  48.850160    1080.087000          5
# 996  2022-02-11 12:00:00    23.836647  47.256435    1705.235156          4
# 997  2022-02-11 13:00:00    23.005340  48.720501    1320.285281          6
# 998  2022-02-11 14:00:00    25.138365  31.306459    1309.079719          3
# 999  2022-02-11 15:00:00    23.051165  42.615421    1018.140606          6
#
#     HVACUsage LightingUsage  RenewableEnergy  DayOfWeek Holiday  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Timestamp          1000 non-null   object
#  1   Temperature        1000 non-null   float64
#  2   Humidity           1000 non-null   float64
#  3   SquareFootage      1000 non-null   float64
#  4   Occupancy          1000 non-null   int64
#  5   HVACUsage          1000 non-null   object
#  6   LightingUsage      1000 non-null   object
#  7   RenewableEnergy    1000 non-null   float64
#  8   DayOfWeek          1000 non-null   object
#  9   Holiday            1000 non-null   object
#  10  EnergyConsumption  1000 non-null   float64
# dtypes: float64(5), int64(1), object(5)
# memory usage: 86.1+ KB

# %%
data.columns
# Out:
# Index(['Timestamp', 'Temperature', 'Humidity', 'SquareFootage', 'Occupancy',
#        'HVACUsage', 'LightingUsage', 'RenewableEnergy', 'DayOfWeek', 'Holiday',
#        'EnergyConsumption'],
#       dtype='object')

# %%
data.skew()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_6960\1188251951.py:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.skew()
# Temperature          0.088428
# Humidity            -0.066463
# SquareFootage       -0.019441
# Occupancy           -0.055229
# RenewableEnergy     -0.021597
# EnergyConsumption    0.027399
# dtype: float64

# %%
data.kurtosis()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_6960\2361870383.py:1: FutureWarning: The default value of numeric_only in DataFrame.kurt is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.kurtosis()
# Temperature         -1.115196
# Humidity            -1.133748
# SquareFootage       -1.229895
# Occupancy           -1.233842
# RenewableEnergy     -1.220440
# EnergyConsumption   -0.300154
# dtype: float64

# %%
data.duplicated().any()
# Out:
# False

# %%
data.isnull().any()
# Out:
# Timestamp            False
# Temperature          False
# Humidity             False
# SquareFootage        False
# Occupancy            False
# HVACUsage            False
# LightingUsage        False
# RenewableEnergy      False
# DayOfWeek            False
# Holiday              False
# EnergyConsumption    False
# dtype: bool

# %%
data.corr()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_6960\2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                    Temperature  Humidity  SquareFootage  Occupancy  \
# Temperature           1.000000 -0.034032       0.004551  -0.003490
# Humidity             -0.034032  1.000000      -0.014651   0.004766
# SquareFootage         0.004551 -0.014651       1.000000   0.009696
# Occupancy            -0.003490  0.004766       0.009696   1.000000
# RenewableEnergy      -0.001350  0.002052       0.022196   0.013680
# EnergyConsumption     0.696410 -0.093583      -0.001129   0.186580
#
#                    RenewableEnergy  EnergyConsumption
# Temperature              -0.001350           0.696410
# Humidity                  0.002052          -0.093583
# ...

# %%
data.describe()
# Out:
#        Temperature     Humidity  SquareFootage    Occupancy  RenewableEnergy  \
# count  1000.000000  1000.000000    1000.000000  1000.000000      1000.000000
# mean     24.982026    45.395412    1500.052488     4.581000        15.132813
# std       2.836850     8.518905     288.418873     2.865598         8.745917
# min      20.007565    30.015975    1000.512661     0.000000         0.006642
# 25%      22.645070    38.297722    1247.108548     2.000000         7.628385
# 50%      24.751637    45.972116    1507.967426     5.000000        15.072296
# 75%      27.418174    52.420066    1740.340165     7.000000        22.884064
# max      29.998671    59.969085    1999.982252     9.000000        29.965327
#
#        EnergyConsumption
# count        1000.000000
# mean           77.055873
# std             8.144112
# min            53.263278
# 25%            71.544690
# 50%            76.943696
# 75%            82.921742
# max            99.201120

# %%
plt.figure(figsize = (8,8))
sn.heatmap(data.corr(),annot = True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_6960\633172310.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sn.heatmap(data.corr(),annot = True)
# <Axes: >

# %%
plt.figure(figsize = (24,8))
sn.lineplot(x = "Temperature" , y = "EnergyConsumption" , data = data )
# Out:
# <Axes: xlabel='Temperature', ylabel='EnergyConsumption'>

# %%
plt.figure(figsize = (24,8))
sn.distplot(data["EnergyConsumption"] , color = "Red")
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_6960\743247817.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(data["EnergyConsumption"] , color = "Red")
# <Axes: xlabel='EnergyConsumption', ylabel='Density'>

# %%
data.head()
# Out:
#              Timestamp  Temperature   Humidity  SquareFootage  Occupancy  \
# 0  2022-01-01 00:00:00    25.139433  43.431581    1565.693999          5
# 1  2022-01-01 01:00:00    27.731651  54.225919    1411.064918          1
# 2  2022-01-01 02:00:00    28.704277  58.907658    1755.715009          2
# 3  2022-01-01 03:00:00    20.080469  50.371637    1452.316318          1
# 4  2022-01-01 04:00:00    23.097359  51.401421    1094.130359          9
#
#   HVACUsage LightingUsage  RenewableEnergy  DayOfWeek Holiday  \
# 0        On           Off         2.774699     Monday      No
# 1        On            On        21.831384   Saturday      No
# 2       Off           Off         6.764672     Sunday      No
# 3       Off            On         8.623447  Wednesday      No
# 4        On           Off         3.071969     Friday      No
#
#    EnergyConsumption
# 0          75.364373
# 1          83.401855
# 2          78.270888
# 3          56.519850
# 4          70.811732

# %%
data.columns
# Out:
# Index(['Timestamp', 'Temperature', 'Humidity', 'SquareFootage', 'Occupancy',
#        'HVACUsage', 'LightingUsage', 'RenewableEnergy', 'DayOfWeek', 'Holiday',
#        'EnergyConsumption'],
#       dtype='object')

# %%
for i in ['EnergyConsumption' , 'Humidity','RenewableEnergy','SquareFootage','Temperature']:
    sn.distplot(data[i],color = "Green")
    plt.title(i)
    plt.grid()
    plt.tight_layout()
    plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_6960\2116112033.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(data[i],color = "Green")
# C:\Users\user\AppData\Local\Temp\ipykernel_6960\2116112033.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
for i in ['EnergyConsumption' , 'Humidity','RenewableEnergy','SquareFootage','Temperature']:
    sn.boxplot(data[i] , color = 'red')
    plt.title(i)
    plt.grid()
    plt.tight_layout()
    plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
data
# Out:
#                Timestamp  Temperature   Humidity  SquareFootage  Occupancy  \
# 0    2022-01-01 00:00:00    25.139433  43.431581    1565.693999          5
# 1    2022-01-01 01:00:00    27.731651  54.225919    1411.064918          1
# 2    2022-01-01 02:00:00    28.704277  58.907658    1755.715009          2
# 3    2022-01-01 03:00:00    20.080469  50.371637    1452.316318          1
# 4    2022-01-01 04:00:00    23.097359  51.401421    1094.130359          9
# ..                   ...          ...        ...            ...        ...
# 995  2022-02-11 11:00:00    28.619382  48.850160    1080.087000          5
# 996  2022-02-11 12:00:00    23.836647  47.256435    1705.235156          4
# 997  2022-02-11 13:00:00    23.005340  48.720501    1320.285281          6
# 998  2022-02-11 14:00:00    25.138365  31.306459    1309.079719          3
# 999  2022-02-11 15:00:00    23.051165  42.615421    1018.140606          6
#
#     HVACUsage LightingUsage  RenewableEnergy  DayOfWeek Holiday  \
# ...

# %%
data = data.drop(['Timestamp'] ,axis = 1)

# %%
data
# Out:
#      Temperature   Humidity  SquareFootage  Occupancy HVACUsage LightingUsage  \
# 0      25.139433  43.431581    1565.693999          5        On           Off
# 1      27.731651  54.225919    1411.064918          1        On            On
# 2      28.704277  58.907658    1755.715009          2       Off           Off
# 3      20.080469  50.371637    1452.316318          1       Off            On
# 4      23.097359  51.401421    1094.130359          9        On           Off
# ..           ...        ...            ...        ...       ...           ...
# 995    28.619382  48.850160    1080.087000          5       Off           Off
# 996    23.836647  47.256435    1705.235156          4       Off            On
# 997    23.005340  48.720501    1320.285281          6       Off            On
# 998    25.138365  31.306459    1309.079719          3        On           Off
# 999    23.051165  42.615421    1018.140606          6       Off            On
#
# ...

# %%
data = pd.get_dummies(data).astype(int)

# %%
data
# Out:
#      Temperature  Humidity  SquareFootage  Occupancy  RenewableEnergy  \
# 0             25        43           1565          5                2
# 1             27        54           1411          1               21
# 2             28        58           1755          2                6
# 3             20        50           1452          1                8
# 4             23        51           1094          9                3
# ..           ...       ...            ...        ...              ...
# 995           28        48           1080          5               21
# 996           23        47           1705          4               25
# 997           23        48           1320          6                0
# 998           25        31           1309          3               20
# 999           23        42           1018          6                2
#
#      EnergyConsumption  HVACUsage_Off  HVACUsage_On  LightingUsage_Off  \
# ...

# %%
q1 = data["EnergyConsumption"].quantile(0.25)
q3 = data["EnergyConsumption"].quantile(0.75)
iqr = q3-q1
upper_bound = q3+1.5*(iqr)
lower_bound = q1-1.5*(iqr)

data = data[~((data["EnergyConsumption"]>upper_bound))|((data["EnergyConsumption"]<lower_bound))]

# %%
sn.boxplot(data["EnergyConsumption"])
# Out:
# <Axes: >

# %%
x = data.drop(["EnergyConsumption"],axis = 1)
y = data["EnergyConsumption"]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

# %%
data = data.fillna(0)

# %%
data
# Out:
#      Temperature  Humidity  SquareFootage  Occupancy  RenewableEnergy  \
# 0             25        43           1565          5                2
# 1             27        54           1411          1               21
# 2             28        58           1755          2                6
# 3             20        50           1452          1                8
# 4             23        51           1094          9                3
# ..           ...       ...            ...        ...              ...
# 995           28        48           1080          5               21
# 996           23        47           1705          4               25
# 997           23        48           1320          6                0
# 998           25        31           1309          3               20
# 999           23        42           1018          6                2
#
#      EnergyConsumption  HVACUsage_Off  HVACUsage_On  LightingUsage_Off  \
# ...

# %%
x_train,x_test,y_train,y_test = train_test_split(x, y , random_state = 42 , test_size = 0.20)

# %%
x_train.shape , x_test.shape
# Out:
# ((799, 18), (200, 18))

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
model = LinearRegression()

# %%
model.fit(x_train , y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array([79.53187061, 72.90223194, 67.06824757, 78.48499561, 80.66199757,
#        82.96937061, 71.63660694, 74.46668507, 66.16199757, 77.94324757,
#        70.25062061, 77.05262257, 71.89124561, 66.88856007, 80.05262257,
#        70.06824757, 69.09949757, 80.22449757, 78.50574757, 79.46937061,
#        75.93812061, 82.18348194, 70.39124561, 74.28699757, 75.15687061,
#        79.43812061, 80.20374561, 79.62562061, 77.19324757, 72.78699757,
#        79.82874561, 81.02137257, 78.79749561, 74.89124561, 74.67249561,
#        74.21937061, 71.93812061, 87.50574757, 78.93812061, 68.89710499,
#        76.48231007, 71.89637257, 77.11780811, 71.79749561, 68.93812061,
#        74.56312061, 71.19324757, 85.94324757, 73.39124561, 83.83460499,
#        69.96473194, 77.00062061, 79.29749561, 78.00062061, 88.53699757,
#        68.57874561, 78.39637257, 64.95887257, 68.98231007, 81.89710499,
#        87.88074757, 80.22449757, 81.28699757, 84.06312061, 73.62562061,
# ...

# %%
mse = np.mean((y_test-y_pred)**2)

# %%
mse
# Out:
# 24.949036555846273

# %%
rmse = np.sqrt(mse)

# %%
rmse
# Out:
# 4.99490105566129

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model_random = RandomForestRegressor(n_estimators = 150 , max_features = 5)

# %%
model_random.fit(x_train , y_train)
# Out:
# RandomForestRegressor(max_features=5, n_estimators=150)

# %%
y_pred_rand = model_random.predict(x_test)

# %%
y_pred_rand
# Out:
# array([77.53333333, 76.1       , 68.84      , 77.38      , 80.3       ,
#        82.46      , 72.76666667, 75.39333333, 67.71333333, 76.58666667,
#        72.88      , 76.8       , 74.57333333, 67.49333333, 81.44      ,
#        71.84      , 71.14666667, 76.59333333, 78.86      , 81.76      ,
#        75.15333333, 82.25333333, 72.05333333, 76.63333333, 77.68      ,
#        80.7       , 80.08      , 81.41333333, 74.75333333, 74.06666667,
#        78.97333333, 78.89333333, 76.82      , 72.94666667, 74.36      ,
#        74.59333333, 70.87333333, 86.25333333, 80.52666667, 66.24      ,
#        75.18666667, 72.06666667, 78.36      , 73.42666667, 70.8       ,
#        74.93333333, 73.37333333, 84.56666667, 71.15333333, 84.75333333,
#        69.59333333, 77.29333333, 82.64666667, 76.20666667, 88.47333333,
#        68.56666667, 73.3       , 69.65333333, 71.18      , 81.58666667,
#        82.89333333, 79.66      , 77.32666667, 82.18      , 74.52666667,
# ...

# %%
mse_ran = np.mean((y_test-y_pred_rand)**2)

# %%
print(mse_ran)
# Out:
# 27.676147500000003

# %%
rmse = np.sqrt(mse_ran)

# %%
print(rmse)
# Out:
# 5.260812437257196
